# %% [markdown]
# # SQL Interview Questions  - Quiz
#
#
# ## Introduction
#
# This quiz contains questions on topics you can expect to see in an interview pertaining to SQL and Relational Databases. Some of them are multiple choice, while some are short answer. For these short answer questions, double click on the Jupyter Notebook and type your answer below the line.
#
# ## Question 1
#
# What are the 4 main datatypes in SQLite3? Can we use other common types from other kinds of SQL?
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# The four main datatpes in SQLite 3 are TEXT, INTEGERS, REAL & BLOB. Yes you can use other common datatypes from other kinds of SQL, such as INT, which would get lumped in as an INTEGER.
#
#
#
#
# ## Question 2
#
# Explain the relationship between **Primary Keys** and **Foreign Keys**.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# Primary Keys the key that represents the column in the table that you want to execute a join ON. The Foreign Key is a matching column in another table, that the table joins WITH.
#
#
#
# ## Question 3
#
# Explain the different types of relationships entities can have in a SQL database.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# One-to-One: Ex: One person has one SSN.
#
# One-to-Many: One teacher has many students, if you were connecting a teachers and students table for a school database.
#
# Many-to-Many: Many students take many classes
#
#
# ## Question 4
#
# Explain the various types of JOINs possible with SQL.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
# You can do INNER JOINS, OUTER JOINS and FULL JOINS.
#
# An Inner Join will return all rows that match in the Table with the Primary Key, the Outer Join will return all of the rows that match in the Table with the Foreign Key, or th
#
#
#
# ## Question 5
#
# Explain the relationship between Aggregate functions and GROUP BY statements.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# Aggregate functions are trying to calculate something, whether that is getting an average of a set of values in a table, or counting the number of unique values in a specific column. Group by statements, as the name suggests, are meant for organizing your table and contextual scope into groups of records within a table.
#
#
# ## Question 6
#
# What role do Associative Entities play (JOIN Tables) in many-to-many JOINs?
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# Join Tables are a single table so that you use to join a many-to-many relationship. They take the respe
#
#
# ## Summary
#
# In this lesson, we practiced answering open-ended interview questions for SQL and Relational Databases.
